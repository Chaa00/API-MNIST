# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaa00/API-MNIST/blob/main/API_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
inputs=keras.Input(shape=(784,), name="img")
out1=layers.Dense(64,activation='relu')(inputs)
out2=layers.Dense(64,activation='relu')(out1)
outputs=layers.Dense(10,activation='softmax')(out2)
model=keras.Model(inputs=inputs,outputs=outputs,name='mnist_model')
batch_size = 128
epochs = 10
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255



model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])



history= model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.4313 - accuracy: 0.8768 - val_loss: 0.1615 - val_accuracy: 0.9537
# Epoch 2/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1727 - accuracy: 0.9504 - val_loss: 0.1315 - val_accuracy: 0.9630
# Epoch 3/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1286 - accuracy: 0.9626 - val_loss: 0.1018 - val_accuracy: 0.9700
# Epoch 4/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.1012 - accuracy: 0.9700 - val_loss: 0.0964 - val_accuracy: 0.9713
# Epoch 5/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0850 - accuracy: 0.9747 - val_loss: 0.0879 - val_accuracy: 0.9737
# Epoch 6/10
# 422/422 [==============================] - 1s 3ms/step - loss: 0.0723 - accuracy: 0.9780 - val_loss: 0.0863 - val_accuracy: 0.9758
# Epoch 7/10
# ...

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0]) #Test loss: 0.0296396646054
print('Test accuracy:', score[1]) #Test accuracy: 0.9904
# Out:
# Test loss: 0.09038525074720383
# Test accuracy: 0.9760000109672546

# %%
# plotting the metrics
import matplotlib.pyplot as plt

fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.tight_layout()
fig
